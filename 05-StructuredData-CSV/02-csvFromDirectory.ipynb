# %%
from langchain.document_loaders import CSVLoader, DirectoryLoader
from pathlib import Path
from re import sub
from datetime import datetime

SEPRATOR = ","
QUOTEDSTRING = '"'
ISMULTITHRD = True
MAXCONCRNCY = 3

class CSVProcessFromDirectory:

    def __init__(self, folderPath : Path = None, fileFormat : str = "csv"):

        self.folderPath = folderPath
        self.fileFormat = fileFormat.lower()
        self.loaderClass = None
        self.loaderArgmnt = None
        self.directoryLoader = DirectoryLoader(
            path=self.folderPath,
            glob=f"**/*.{self.fileFormat}",
            loader_cls= self.loaderClass,
            loader_kwargs={
                "csv_args" : 
                        {
                        "delimiter": ",",
                            "quotechar": '"'
                        }
                    },
            use_multithreading= ISMULTITHRD,
            max_concurrency= MAXCONCRNCY
        )


    @property
    def folderPath(self) -> Path:
        return self.__folderPath
    
    @folderPath.setter
    def folderPath(self, folderPath : Path):

        if str(folderPath) == "" or folderPath == None:
            raise AttributeError("Folder Path is not Valid. Please provide Proper Folder Path")
        elif not folderPath.exists():
            folderPath.mkdir(parents=True, exist_ok=True)
        else:
            print(f"Path {folderPath} Exists")

        self.__folderPath = folderPath

    @property
    def fileFormat(self) -> str:
        return self.__fileFormat.lower()
    
    @fileFormat.setter
    def fileFormat(self, fileFormat: str):
        self.__fileFormat = fileFormat.lower()


    @property
    def loaderClass(self) -> str:
        return self.__loaderClass
    
    @loaderClass.setter
    def loaderClass(self, loaderClass : str):

        if self.fileFormat == "csv":
            self.__loaderClass = CSVLoader
        else:
            raise AttributeError("File Format is Other then CSV")
        
    @property
    def loaderArgmnt(self) -> dict:
        return self.__loaderArgmnt
    
    @loaderArgmnt.setter
    def loaderArgmnt(self , arg):

        if self.fileFormat == "csv":
            arg = {
                "delimiter": SEPRATOR,
                "quotechar" : QUOTEDSTRING
            }
        else:
            raise AttributeError("Not CSV Format")
        
        self.__loaderArgmnt = arg

    @property
    def CSVInDirToChunks(self) -> list:

        return self.directoryLoader.load()
    

path = Path("../data/csv")
obj = CSVProcessFromDirectory(path, "csv")
chunks = obj.CSVInDirToChunks
for item in chunks:
    print(item.metadata)
    print(item.page_content)
    print('---------------------')
# Out:
# Path ..\data\csv Exists
# {'source': '..\\data\\csv\\businesscentral_clov.csv', 'row': 0}
# sourcelocation: Clov
# pk_uuid: c95d2918-a0c7-4456-90eb-713e1437de13
# number: DAN.REBECK
# firstname: Dan
# lastname: Rebeck
# RoleGroup: Dynamics 365 for Accountants
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_clov.csv', 'row': 1}
# sourcelocation: Clov
# pk_uuid: baed7392-dd8a-47d6-91f4-ea268cda3191
# number: MATTHEW.BOHUN-APONTE
# firstname: Matthew
# lastname: Bohun-Aponte
# RoleGroup: Dynamics 365 for Accountants
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_clov.csv', 'row': 2}
# sourcelocation: Clov
# pk_uuid: fb59eb2d-2243-488e-8ecb-93172e8d5d93
# number: SARAH.HIBIT
# firstname: Sarah
# lastname: Hibit
# RoleGroup: Dynamics 365 for Accountants
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_clov.csv', 'row': 3}
# sourcelocation: Clov
# pk_uuid: 3f8bb255-d4c1-4389-919d-ec96ebefb1e9
# number: JILLIAN.GOLDMAN
# firstname: Jillian
# lastname: Goldman
# RoleGroup: Dynamics 365 Accounts payable
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_clov.csv', 'row': 4}
# sourcelocation: Clov
# pk_uuid: f401a55f-bf5a-4301-a0bd-fdf20d663804
# number: BARBARA.RONAN
# firstname: Barbara
# lastname: Ronan
# RoleGroup: Dynamics 365 Accounts payable
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_clov.csv', 'row': 5}
# sourcelocation: Clov
# pk_uuid: ff57a337-b5e1-4d0d-bcc4-604442c8ec3d
# number: CINDY.HADEN
# firstname: Cindy
# lastname: Haden
# RoleGroup: Dynamics 365 for Accountants
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_maverick.csv', 'row': 0}
# sourcelocation: Maverick
# pk_uuid: d642062a-9fae-439b-8d23-9232b1c2c169
# number: LWHITON
# firstname: Lu
# lastname: Whiton
# RoleGroup: Dynamics 365 for Accountants
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_maverick.csv', 'row': 1}
# sourcelocation: Maverick
# pk_uuid: 2a289ae3-150e-4d7e-9883-2824064bbc7b
# number: ASHLEY.COLLINS
# firstname: Ashley
# lastname: Collins
# RoleGroup: Dynamics 365 for Accountants
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 0}
# sourcelocation: Stouse
# pk_uuid: 7af3941c-60e7-40a2-9533-c89883f5f141
# number: MATTHEW.MULDER 1
# firstname: Matthew
# lastname: Mulder
# RoleGroup: Dyn. 365 Edit Cost Accounting,Dynamics 365 for Accountants,Stouse Accounting ,Dyn. 365 View Cost Accounting
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 1}
# sourcelocation: Stouse
# pk_uuid: 809cd4bb-adc8-4127-8a0e-7383279cf756
# number: ZION.JOHN
# firstname: Zion
# lastname: John
# RoleGroup: Dynamics 365 Accounts payable
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 2}
# sourcelocation: Stouse
# pk_uuid: c60acb2c-434b-414b-bc20-878b0facdf4c
# number: JORDAN.BRINKS 1
# firstname: Jordan
# lastname: Brinks
# RoleGroup: Dynamics 365 for Accountants
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 3}
# sourcelocation: Stouse
# pk_uuid: f022cb65-c9f0-4177-98ad-6e10ea37c4e4
# number: NICK.THOMASSON
# firstname: Nick
# lastname: Thomasson
# RoleGroup: Dyn. 365 Edit Cost Accounting,Dynamics 365 for Accountants,Dyn. 365 View Cost Accounting
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 4}
# sourcelocation: Stouse
# pk_uuid: c5a3137b-7ded-4bbf-9acd-4271acd2ee5b
# number: JORDAN.BRINKS
# firstname: Jordan
# lastname: Brinks
# RoleGroup: Dynamics 365 for Accountants
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 5}
# sourcelocation: Stouse
# pk_uuid: 8cf334b5-dee0-4c0c-8818-4345fb0b97e5
# number: ELIZABETH.STOOPS
# firstname: Elizabeth
# lastname: Stoops
# RoleGroup: Dynamics 365 for Accountants
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 6}
# sourcelocation: Stouse
# pk_uuid: 219c01dc-a20f-4412-89a3-c01c86c7791c
# number: AIDAN.HAMMEL
# firstname: Aidan
# lastname: Hammel
# RoleGroup: Dynamics 365 Accounts payable
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 7}
# sourcelocation: Stouse
# pk_uuid: 01c6444a-c06f-4065-a98a-358b2dd6cb1d
# number: TWILSON
# firstname: Tammy
# lastname: Wilson
# RoleGroup: Dynamics 365 Accounts payable
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 8}
# sourcelocation: Stouse
# pk_uuid: eca38ee8-b10e-47a4-879d-bdc95a1372ca
# number: DAMOLA.OYIN
# firstname: Damola
# lastname: Oyin
# RoleGroup: Dynamics 365 Accounts payable
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 9}
# sourcelocation: Stouse
# pk_uuid: 8b9f7a03-b875-48ca-b4d3-9eb771d88043
# number: JESSICA.ZHENG
# firstname: Jessica
# lastname: Zheng
# RoleGroup: Dynamics 365 for Accountants
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 10}
# sourcelocation: Stouse
# pk_uuid: c9d309dd-360b-4690-85b6-5b1f8c7f62e5
# number: DEREK.ESHNAUR 1
# firstname: Derek
# lastname: Eshnaur
# RoleGroup: Dyn. 365 Edit Cost Accounting,Dynamics 365 for Accountants,Stouse Accounting ,Dyn. 365 View Cost Accounting
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 11}
# sourcelocation: Stouse
# pk_uuid: dc67258b-df0b-4d47-b3e4-6042ab5d5b9b
# number: KAREN.DODD
# firstname: Karen
# lastname: Dodd
# RoleGroup: Dyn. 365 Edit Cost Accounting,Dynamics 365 for Accountants,Dyn. 365 View Cost Accounting
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 12}
# sourcelocation: Stouse
# pk_uuid: fbfa5dc9-79dd-42f2-8702-0678069c2384
# number: EWOUT.VOCKING
# firstname: Ewout
# lastname: Vocking
# RoleGroup: Dynamics 365 Accounts payable
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 13}
# sourcelocation: Stouse
# pk_uuid: b003a9a8-736e-414d-a9d4-15e9b1094c70
# number: ALEXANDRA.STUCKY
# firstname: Alexandra
# lastname: Stucky
# RoleGroup: Dyn. 365 Edit Cost Accounting,Dynamics 365 for Accountants,Stouse Accounting ,Dyn. 365 View Cost Accounting
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 14}
# sourcelocation: Stouse
# pk_uuid: d489d298-caef-4c43-89bd-5607b6363159
# number: CORTNEY.WOODRUFF 1
# firstname: Cortney
# lastname: Woodruff
# RoleGroup: Dynamics 365 for Accountants
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 15}
# sourcelocation: Stouse
# pk_uuid: 8ac7b289-9040-449e-8412-477e47efd77d
# number: DEREK.ESHNAUR
# firstname: Derek
# lastname: Eshnaur
# RoleGroup: Dyn. 365 Edit Cost Accounting,Dynamics 365 for Accountants,Stouse Accounting ,Dyn. 365 View Cost Accounting
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 16}
# sourcelocation: Stouse
# pk_uuid: 9eb107ac-9db0-49d9-a7c2-fa4af8b15ff6
# number: KEVIN.KIRBY
# firstname: Kevin
# lastname: Kirby
# RoleGroup: Dynamics 365 for Accountants
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 17}
# sourcelocation: Stouse
# pk_uuid: baed7392-dd8a-47d6-91f4-ea268cda3191
# number: MATTHEW.BOHUN-APONTE
# firstname: Matthew
# lastname: Bohun-Aponte
# RoleGroup: Dynamics 365 for Accountants
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 18}
# sourcelocation: Stouse
# pk_uuid: 2347bb50-31ae-4bb1-af39-4aa9dfb00cbb
# number: SUSIE.HANN 1
# firstname: Susie
# lastname: Hann
# RoleGroup: Dynamics 365 for Accountants,Dyn. 365 Accounts receivable
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 19}
# sourcelocation: Stouse
# pk_uuid: fac1cea6-08c9-4aea-b66e-5051ea8a99f8
# number: SUSIE.HANN
# firstname: Susie
# lastname: Hann
# RoleGroup: Dynamics 365 for Accountants,Dyn. 365 Accounts receivable
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 20}
# sourcelocation: Stouse
# pk_uuid: 2ec7eab8-64f7-4be8-b17d-98dc42ee816e
# number: LINDA.SHAFFER
# firstname: Linda
# lastname: Shaffer
# RoleGroup: Dynamics 365 for Accountants
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 21}
# sourcelocation: Stouse
# pk_uuid: cec8772b-3abf-4f98-b20d-7d52cddd0719
# number: DENEA.LOVERN
# firstname: Denea
# lastname: Lovern
# RoleGroup: Dynamics 365 for Accountants
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 22}
# sourcelocation: Stouse
# pk_uuid: d1b6164e-fce4-4b5c-93c0-504ebade85af
# number: CORTNEY.WOODRUFF
# firstname: Cortney
# lastname: Woodruff
# RoleGroup: Dynamics 365 for Accountants
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 23}
# sourcelocation: Stouse
# pk_uuid: 8427c9be-61ee-426e-bc5d-a2861d8a1637
# number: SHANNON.LINKS
# firstname: Shannon
# lastname: Links
# RoleGroup: Dynamics 365 for Accountants,Dyn. 365 Accounts receivable
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 24}
# sourcelocation: Stouse
# pk_uuid: 424e6fee-53e7-4c51-8aaf-48b0ad75e451
# number: JANET.BEARD
# firstname: Janet
# lastname: Beard
# RoleGroup: Dynamics 365 for Accountants
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 25}
# sourcelocation: Stouse
# pk_uuid: 0f7f3df2-e002-4aa7-b21f-48e324daef9f
# number: KATHLEEN.STRAWDER
# firstname: Kathleen
# lastname: Strawder
# RoleGroup: Dynamics 365 for Accountants
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 26}
# sourcelocation: Stouse
# pk_uuid: 808b5dec-44a8-4cc0-90d9-70ab2e1694bb
# number: ADMNTHOMASSON
# firstname:
# lastname:
# RoleGroup: Dynamics 365 for Accountants
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 27}
# sourcelocation: Stouse
# pk_uuid: 7b958b71-6281-451c-bf81-9d452e9a5929
# number: ALEX.SHARTZER
# firstname: Alex
# lastname: Shartzer
# RoleGroup: Dynamics 365 for Accountants
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 28}
# sourcelocation: Stouse
# pk_uuid: 92db467d-7c1e-4733-97e8-94c0ae6d0a7b
# number: MATTHEW.MULDER
# firstname: Matthew
# lastname: Mulder
# RoleGroup: Dyn. 365 Edit Cost Accounting,Dynamics 365 for Accountants,Stouse Accounting ,Dyn. 365 View Cost Accounting
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 29}
# sourcelocation: Stouse
# pk_uuid: 71004b2a-1fa6-42ce-90bb-3e34c1fa0a75
# number: TINA.SCHAEFER
# firstname: Tina
# lastname: Schaefer
# RoleGroup: Dynamics 365 for Accountants
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 30}
# sourcelocation: Stouse
# pk_uuid: c6f623eb-1369-4193-b768-632916b3b835
# number: LONNIE.CLAY
# firstname: Lonnie
# lastname: Clay
# RoleGroup: Dynamics 365 for Accountants
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 31}
# sourcelocation: Stouse
# pk_uuid: 00f77862-cd56-4cf2-8b33-e6069c1ca16d
# number: CAILEE.FULTZ 1
# firstname: Cailee
# lastname: Fultz
# RoleGroup: Dynamics 365 for Accountants
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 32}
# sourcelocation: Stouse
# pk_uuid: 25d093d5-dd48-402b-b38f-df79a9a6dfcf
# number: KWITSCHER
# firstname: Kimberly
# lastname: Witscher
# RoleGroup: Dynamics 365 Accounts payable
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 33}
# sourcelocation: Stouse
# pk_uuid: 98015c5c-d332-4872-b491-4c14bf4a9a40
# number: LARRY.SHAW
# firstname: Larry
# lastname: Shaw
# RoleGroup: Dynamics 365 for Accountants
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 34}
# sourcelocation: Stouse
# pk_uuid: 4a1f6ba6-33ab-4c7b-bbb6-8324eb184cc1
# number: ELIZABETH.STOOPS 1
# firstname: Elizabeth
# lastname: Stoops
# RoleGroup: Dynamics 365 for Accountants
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 35}
# sourcelocation: Stouse
# pk_uuid: a6a9e8ce-72c2-4444-ae61-2fde233b74d3
# number: SVC_POWERBI
# firstname:
# lastname:
# RoleGroup: Dynamics 365 for Accountants
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 36}
# sourcelocation: Stouse
# pk_uuid: 1cdc49e8-dcb8-4639-af8a-faba697fd387
# number: KYLIE.NEWTON
# firstname: Kylie
# lastname: Newton
# RoleGroup: Dynamics 365 for Accountants
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 37}
# sourcelocation: Stouse
# pk_uuid: fb59eb2d-2243-488e-8ecb-93172e8d5d93
# number: SARAH.HIBIT
# firstname: Sarah
# lastname: Hibit
# RoleGroup: Dynamics 365 for Accountants
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 38}
# sourcelocation: Stouse
# pk_uuid: d702f58f-a1c8-40c3-b4bd-b10d23c3db5b
# number: LISA.FOSTER 1
# firstname: Lisa
# lastname: Foster
# RoleGroup: Dynamics 365 for Accountants
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 39}
# sourcelocation: Stouse
# pk_uuid: 8386dc6e-5774-49e6-8294-f1af610a8477
# number: PARVEEZ.SHARIEFF
# firstname: Parveez
# lastname: Sharieff
# RoleGroup: Dynamics 365 Accounts payable
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 40}
# sourcelocation: Stouse
# pk_uuid: 37df67c2-d9c9-490e-aae7-2c9a74e4efaf
# number: BEVERLY.HALL
# firstname: Beverly
# lastname: Hall
# RoleGroup: Dynamics 365 Accounts payable
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 41}
# sourcelocation: Stouse
# pk_uuid: bf025790-b2ac-4166-8cf8-fa5d1bb5ac53
# number: CREDIT.01
# firstname:
# lastname:
# RoleGroup: Dynamics 365 for Accountants
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 42}
# sourcelocation: Stouse
# pk_uuid: f059149d-4765-42ad-8e4b-9dd0e0e4a33d
# number: CFUNKE
# firstname: Chase
# lastname: Funke
# RoleGroup: Power BI Core Admin
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 43}
# sourcelocation: Stouse
# pk_uuid: 5376b8a2-fcbf-47c2-9195-9e414223a45c
# number: NATALIE.STOOPS
# firstname: Natalie
# lastname: Stoops
# RoleGroup: Dynamics 365 for Accountants
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 44}
# sourcelocation: Stouse
# pk_uuid: ff57a337-b5e1-4d0d-bcc4-604442c8ec3d
# number: CINDY.HADEN
# firstname: Cindy
# lastname: Haden
# RoleGroup: Dynamics 365 for Accountants
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 45}
# sourcelocation: Stouse
# pk_uuid: bfa83be6-936e-4d62-9e65-45ef49fb368c
# number: SVC_ALTERYX
# firstname:
# lastname:
# RoleGroup: Dynamics 365 for Accountants
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 46}
# sourcelocation: Stouse
# pk_uuid: 0b7a07c1-b1d1-42d1-8cd8-a357c0eb549a
# number: NICK.THOMASSON 1
# firstname: Nick
# lastname: Thomasson
# RoleGroup: Dyn. 365 Edit Cost Accounting,Dynamics 365 for Accountants,Dyn. 365 View Cost Accounting
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 47}
# sourcelocation: Stouse
# pk_uuid: 3ee01ab7-15fc-4053-8dba-adf76e49b4c2
# number: SARAH.HIBIT 1
# firstname: Sarah
# lastname: Hibit
# RoleGroup: Dynamics 365 for Accountants
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 48}
# sourcelocation: Stouse
# pk_uuid: 7ab5ab92-1792-4bf1-b971-65dd9802d8ea
# number: CAILEE.FULTZ
# firstname: Cailee
# lastname: Fultz
# RoleGroup: Dynamics 365 for Accountants
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 49}
# sourcelocation: Stouse
# pk_uuid: edf65b92-e2a4-4c5d-a958-540388de752f
# number: BECKY.HENDERSON
# firstname: Becky
# lastname: Henderson
# RoleGroup: Dynamics 365 for Accountants
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 50}
# sourcelocation: Stouse
# pk_uuid: b6e383ee-8022-4d2d-9e69-4501a1639010
# number: MISTY.EMERY
# firstname: Misty
# lastname: Emery
# RoleGroup: Dyn. 365 Edit Cost Accounting,Dynamics 365 for Accountants,Dyn. 365 View Cost Accounting
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 51}
# sourcelocation: Stouse
# pk_uuid: bf3d96be-7521-4b66-b777-3b42d5c562de
# number: LISA.FOSTER
# firstname: Lisa
# lastname: Foster
# RoleGroup: Dynamics 365 for Accountants
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 52}
# sourcelocation: Stouse
# pk_uuid: 1ebe38aa-edf4-4d35-b383-2daa3e6de0ee
# number: TINA.SCHAEFER 1
# firstname: Tina
# lastname: Schaefer
# RoleGroup: Dynamics 365 for Accountants
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 53}
# sourcelocation: Stouse
# pk_uuid: f887772e-dfe5-4fcc-a962-333f53239be6
# number: PATRICK.ROUSE
# firstname: Patrick
# lastname: Rouse
# RoleGroup: Dyn. 365 Edit Cost Accounting,Dynamics 365 for Accountants,Dyn. 365 View Cost Accounting
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 54}
# sourcelocation: Stouse
# pk_uuid: 4fb4e4d4-929b-4ca0-80a5-d77bd40885c2
# number: NEWSHA.NEISHABOORY
# firstname: Newsha
# lastname: Neishaboory
# RoleGroup: Dynamics 365 Accounts payable
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 55}
# sourcelocation: Stouse
# pk_uuid: a42083de-9003-4561-abd0-8a362f695409
# number: DENEA.LOVERN 1
# firstname: Denea
# lastname: Lovern
# RoleGroup: Dynamics 365 for Accountants
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 56}
# sourcelocation: Stouse
# pk_uuid: 8e78d73c-f125-478a-bcb0-5fbb0e8ffe58
# number: BEVERLY.HALL 1
# firstname: Beverly
# lastname: Hall
# RoleGroup: Dynamics 365 Accounts payable
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 57}
# sourcelocation: Stouse
# pk_uuid: 23754e30-a8ca-41e7-a812-a4ec1548e68e
# number: KEVIN.KIRBY 1
# firstname: Kevin
# lastname: Kirby
# RoleGroup: Dynamics 365 for Accountants
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 58}
# sourcelocation: Stouse
# pk_uuid: b0172cfa-e031-4a3a-a8d2-2480383bc31c
# number: ADEATON
# firstname: Ashley
# lastname: Deaton
# RoleGroup: Dynamics 365 Accounts payable
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 59}
# sourcelocation: Stouse
# pk_uuid: c95d2918-a0c7-4456-90eb-713e1437de13
# number: DAN.REBECK
# firstname: Dan
# lastname: Rebeck
# RoleGroup: Dynamics 365 for Accountants
# ---------------------
# {'source': '..\\data\\csv\\businesscentral_stouse.csv', 'row': 60}
# sourcelocation: Stouse
# pk_uuid: 5aca124c-bd97-4509-adbb-6ef79d249c01
# number: JON.SCHULTEIS
# firstname: Jon
# lastname: Schulteis
# RoleGroup: Dynamics 365 for Accountants
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 0}
# sourcelocation: amherst
# pk_uuid: 283C2F9808185446B6E330CA020FF069
# number: 1357
# firstname: Daniel
# lastname: Ashmore
# dept: DA
# RoleGroup: Information Technology,Supply Chain,Accounting Leadership,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 1}
# sourcelocation: amherst
# pk_uuid: 00DF60450194C348B720AE8FF526EE0E
# number: 1380
# firstname: Matthew
# lastname: Shannon
# dept: OS
# RoleGroup: Information Technology,Supply Chain,Standard Press & Finishing,Accounting Leadership,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 2}
# sourcelocation: amherst
# pk_uuid: 400FEDDAF4C0744DBB05B15DCEDB7259
# number: 1331
# firstname: Matthew
# lastname: Warnecke
# dept: G&A
# RoleGroup: Quality Control,Information Technology,Supply Chain,Accounting Leadership,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 3}
# sourcelocation: amherst
# pk_uuid: E2C92D0B2B9B35489DF441A53EF24CF0
# number: 1391
# firstname: Luke
# lastname: Westlake
# dept: BW
# RoleGroup: Quality Control,Information Technology,Supply Chain,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 4}
# sourcelocation: amherst
# pk_uuid: 3A188615EE7B1E4996C8EAAABB6715C4
# number: 745
# firstname: Michael
# lastname: Gengo
# dept: Printing Indirect
# RoleGroup: Supply Chain,Standard Press & Finishing,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 5}
# sourcelocation: amherst
# pk_uuid: 81995E4D5DB4DC418333BB3C111C8E63
# number: 1374
# firstname: John
# lastname: Calabro
# dept: G&A
# RoleGroup: Quality Control,Information Technology,Supply Chain,Accounting Leadership,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 6}
# sourcelocation: amherst
# pk_uuid: 04882426AD2645499D9DD2AA1BD809B2
# number: 1029
# firstname: Bryce
# lastname: Choi
# dept: IT
# RoleGroup: Information Technology,Supply Chain,Standard Press & Finishing,Accounting Leadership,Art / Prepress,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 7}
# sourcelocation: amherst
# pk_uuid: 126365DD2CF80B4D8574AD1902F7ED62
# number: 1155
# firstname: Wanda
# lastname: Gallagher
# dept: Production Support
# RoleGroup: Information Technology,Supply Chain,Accounting Leadership,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 8}
# sourcelocation: amherst
# pk_uuid: 204EE0E59CDAD44F8199FB5E627C06C6
# number: 1216
# firstname: Rusty
# lastname: Hegler
# dept: Manager
# RoleGroup: Information Technology,Supply Chain,Standard Press & Finishing,Accounting Leadership,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 9}
# sourcelocation: amherst
# pk_uuid: 3D3352E42BBECA42B4F1026063E0AD18
# number: 1267
# firstname: Gina
# lastname: Le
# dept: G&A
# RoleGroup: Supply Chain,Accounting Leadership,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 10}
# sourcelocation: amherst
# pk_uuid: 4232AF6EBCB2E543B6DE111A642CD9C7
# number: 1230
# firstname: Jon
# lastname: McManus
# dept: OS
# RoleGroup: Quality Control,Information Technology,Supply Chain,Standard Press & Finishing,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 11}
# sourcelocation: amherst
# pk_uuid: 460494771A5DC742B339A206E9618104
# number: 1074
# firstname: Mitchell
# lastname: Morgan
# dept: Production Support
# RoleGroup: Information Technology,Supply Chain,Standard Press & Finishing,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 12}
# sourcelocation: amherst
# pk_uuid: 74046FE89A0D994DB1EE867031016CA5
# number: 1345
# firstname: Nikayla
# lastname: Teague
# dept: DA
# RoleGroup: Supply Chain,Accounting Leadership,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 13}
# sourcelocation: amherst
# pk_uuid: 95558EA28D42844AB0CA1D9A1EDB36A1
# number: 1189
# firstname: Gunaseelan
# lastname: Palanivel
# dept: Printing Indirect
# RoleGroup: Supply Chain,Standard Press & Finishing,Accounting Leadership,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 14}
# sourcelocation: amherst
# pk_uuid: A26831129E31524B93AEA26A4631D8C2
# number: 1136
# firstname: Michelle
# lastname: Malone
# dept: QC
# RoleGroup: Quality Control,Information Technology,Supply Chain,Accounting Leadership,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 15}
# sourcelocation: amherst
# pk_uuid: AF3F13749962E340B6EF9E8637D5FDAD
# number: 1001
# firstname: Ron
# lastname: Wilson
# dept: Roto 12
# RoleGroup: Supply Chain,Standard Press & Finishing,Accounting Leadership,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 16}
# sourcelocation: amherst
# pk_uuid: C0AC3B1209B086439D18A985ACCC7DC0
# number: 1329
# firstname: Brian
# lastname: Pillo
# dept: Manager
# RoleGroup: Supply Chain,Standard Press & Finishing,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 17}
# sourcelocation: amherst
# pk_uuid: CB07A4F7CB076642972BCCF6C557F344
# number: 1087
# firstname: Morgan
# lastname: Blackstone
# dept: IT
# RoleGroup: Information Technology,Supply Chain
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 18}
# sourcelocation: amherst
# pk_uuid: D7BE81D803865A48ACBF094583813DAD
# number: 826
# firstname: Thomas
# lastname: Raszewski
# dept: Printing Indirect
# RoleGroup: Supply Chain,Standard Press & Finishing,Accounting Leadership,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 19}
# sourcelocation: amherst
# pk_uuid: E851FF13FF4C4E4593EB5540069A343F
# number: 1315
# firstname: Parker
# lastname: Ross
# dept: G&A
# RoleGroup: Quality Control,Information Technology,Supply Chain,Accounting Leadership,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 20}
# sourcelocation: amherst
# pk_uuid: FA57F973671A394394411315C667D04B
# number: 1376
# firstname: Chuck
# lastname: Brunner2
# dept: Press
# RoleGroup: Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 21}
# sourcelocation: amherst
# pk_uuid: FC1F44C68F8A2446B69D0D2E7D044F65
# number: 1369
# firstname: Roy
# lastname: Graham
# dept: Manager
# RoleGroup: Information Technology,Supply Chain,Standard Press & Finishing,Accounting Leadership,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 22}
# sourcelocation: amherst
# pk_uuid: 935EEFC368EA024C9550CB1C316281A4
# number: 1324
# firstname: Kim
# lastname: Witscher
# dept: G&A
# RoleGroup: Supply Chain,Accounting Leadership,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 23}
# sourcelocation: amherst
# pk_uuid: E3B38841AE35834FA23D6FB43AA981CF
# number: 1113
# firstname: Laural
# lastname: Gadison
# dept: Sales & Marketing
# RoleGroup: Supply Chain,Accounting Leadership,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 24}
# sourcelocation: amherst
# pk_uuid: EC2346D55F626846A98317CA743918B4
# number: 1323
# firstname: Ashley
# lastname: Deaton
# dept: G&A
# RoleGroup: Supply Chain,Accounting Leadership,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 25}
# sourcelocation: amherst
# pk_uuid: FDEDD0FFB7638A47AA84CABA439561B6
# number: 888
# firstname: Finance
# lastname: Temp-Ct.
# dept: G&A
# RoleGroup: Supply Chain,Accounting Leadership,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 26}
# sourcelocation: amherst
# pk_uuid: 8D2FBEC175B18941934B73C9C7F3001E
# number: 782
# firstname: Matthew
# lastname: Collins
# dept: Sales & Marketing
# RoleGroup: Information Technology,Supply Chain,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 27}
# sourcelocation: amherst
# pk_uuid: 03AE3355BFF30447BABADC02AA9E4B86
# number: 1281
# firstname: Tom
# lastname: Murphy
# dept: Sales & Marketing
# RoleGroup: Information Technology,Supply Chain,Accounting Leadership,Art / Prepress,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 28}
# sourcelocation: amherst
# pk_uuid: 1656FBE89AF18746A149A68D5EF1648D
# number: 1247
# firstname: Steve
# lastname: Reid
# dept: Sales & Marketing
# RoleGroup: Information Technology,Supply Chain,Accounting Leadership,Art / Prepress,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 29}
# sourcelocation: amherst
# pk_uuid: 2731DDB6808A564F907481D93D6A9928
# number: 1285
# firstname: Nancy
# lastname: Josker
# dept: Graphics
# RoleGroup: Information Technology,Supply Chain,Accounting Leadership,Art / Prepress,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 30}
# sourcelocation: amherst
# pk_uuid: 46C69E1AF5AB7842BE2861793D743000
# number: 1282
# firstname: Tony
# lastname: Dominguez
# dept: Graphics
# RoleGroup: Information Technology,Supply Chain,Accounting Leadership,Art / Prepress,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 31}
# sourcelocation: amherst
# pk_uuid: 57598D7DB26F334B8A67DA4498D9E545
# number: 1188
# firstname: Theresa
# lastname: Gardner
# dept: Sales & Marketing
# RoleGroup: Information Technology,Supply Chain,Accounting Leadership,Art / Prepress,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 32}
# sourcelocation: amherst
# pk_uuid: 67DF3C4961B8484C8D45C3457C9E0F79
# number: 1286
# firstname: Ann
# lastname: Fabio
# dept: Graphics
# RoleGroup: Information Technology,Supply Chain,Accounting Leadership,Art / Prepress,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 33}
# sourcelocation: amherst
# pk_uuid: 695D534F4210B249AEE842FBC9ECC804
# number: 1280
# firstname: Steve
# lastname: Reid
# dept: Sales & Marketing
# RoleGroup: Information Technology,Supply Chain,Accounting Leadership,Art / Prepress,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 34}
# sourcelocation: amherst
# pk_uuid: 6CCB953101638D459E1A73FBCD9E9E55
# number: 1126
# firstname: Tina
# lastname: Schooley
# dept: Sales & Marketing
# RoleGroup: Information Technology,Supply Chain,Accounting Leadership,Art / Prepress,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 35}
# sourcelocation: amherst
# pk_uuid: 76AB0D6D76929144A24924342F904876
# number: 1269
# firstname: Theresa
# lastname: Wells
# dept: Sales & Marketing
# RoleGroup: Information Technology,Supply Chain,Accounting Leadership,Art / Prepress,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 36}
# sourcelocation: amherst
# pk_uuid: C4BBBF787F15B849BBA9AB8CB76F38B9
# number: 1119
# firstname: Iolanda
# lastname: Silva
# dept: Sales & Marketing
# RoleGroup: Information Technology,Supply Chain,Accounting Leadership,Art / Prepress,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 37}
# sourcelocation: amherst
# pk_uuid: CAA0FB0EEA2ACF42A76A324F932F4B71
# number: 1284
# firstname: Adam
# lastname: Beiger
# dept: Graphics
# RoleGroup: Information Technology,Supply Chain,Accounting Leadership,Art / Prepress,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 38}
# sourcelocation: amherst
# pk_uuid: D97933C0C6D74B489F11D69C33FD41F5
# number: 1283
# firstname: David
# lastname: Beaty
# dept: Graphics
# RoleGroup: Information Technology,Supply Chain,Accounting Leadership,Art / Prepress,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 39}
# sourcelocation: amherst
# pk_uuid: DE4FBE7CDDAEED4787F891948B763F8E
# number: 1287
# firstname: Joe
# lastname: Harnish
# dept: Graphics
# RoleGroup: Information Technology,Supply Chain,Accounting Leadership,Art / Prepress,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 40}
# sourcelocation: amherst
# pk_uuid: EA215CBE04E14F42934C5DBCABA9D37F
# number: 943
# firstname: Alex
# lastname: Pozin
# dept: Sales & Marketing
# RoleGroup: Information Technology,Supply Chain,Accounting Leadership,Art / Prepress,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 41}
# sourcelocation: amherst
# pk_uuid: F4837857DE347947BDC7BEE13ADD4976
# number: 1394
# firstname: Heather
# lastname: Webb
# dept: Sales & Marketing
# RoleGroup: Information Technology,Supply Chain,Accounting Leadership,Art / Prepress,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 42}
# sourcelocation: amherst
# pk_uuid: 0740A15AA77E724AA3E2E6A7921AD429
# number: 1164
# firstname: Julio
# lastname: Ramirez
# dept: Production Support
# RoleGroup: Information Technology,Supply Chain,Accounting Leadership,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 43}
# sourcelocation: amherst
# pk_uuid: 251C9E829C4107479D4CCC7C92258552
# number: 1239
# firstname: Erica
# lastname: Nugent
# dept: Logistics
# RoleGroup: Information Technology,Supply Chain,Accounting Leadership,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 44}
# sourcelocation: amherst
# pk_uuid: 281A6B32FB6383408CD6BE3DD6EB250A
# number: 1338
# firstname: Wayne
# lastname: Bell
# dept: Logistics
# RoleGroup: Information Technology,Supply Chain,Accounting Leadership,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 45}
# sourcelocation: amherst
# pk_uuid: 4339AA0CBF4E8846BEA38B51F530D7FD
# number: 950
# firstname: Dianne
# lastname: Belanger
# dept: G&A
# RoleGroup: Information Technology,Supply Chain,Accounting Leadership,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 46}
# sourcelocation: amherst
# pk_uuid: 487E35B43326594C8E5E582372CE021D
# number: 778
# firstname: Simon
# lastname: Gore-Grimes
# dept: Sales & Marketing
# RoleGroup: Information Technology,Supply Chain,Accounting Leadership,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 47}
# sourcelocation: amherst
# pk_uuid: 607456C3B91EF24E8CBE05FA94B5ED97
# number: 1370
# firstname: Ashley
# lastname: Collins
# dept: G&A
# RoleGroup: Information Technology,Supply Chain,Accounting Leadership,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 48}
# sourcelocation: amherst
# pk_uuid: 78039D0B24730F45AA1985086D8790F7
# number: 1057
# firstname: Nancie
# lastname: Brunt
# dept: Sales & Marketing
# RoleGroup: Information Technology,Supply Chain,Accounting Leadership,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 49}
# sourcelocation: amherst
# pk_uuid: 8C56F7B1C872E544B696586B593AC989
# number: 860
# firstname: Mark
# lastname: Harrington
# dept: Logistics
# RoleGroup: Information Technology,Supply Chain,Accounting Leadership,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 50}
# sourcelocation: amherst
# pk_uuid: 942E74ACB0ECD44EB89B87D091AF0271
# number: 1229
# firstname: James
# lastname: Harmon
# dept: Manager
# RoleGroup: Information Technology,Supply Chain,Accounting Leadership,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 51}
# sourcelocation: amherst
# pk_uuid: B681A52C19B2EF448F52BC1AB122A630
# number: 1222
# firstname: Brendan
# lastname: Ferraro
# dept: Production Support
# RoleGroup: Information Technology,Supply Chain,Accounting Leadership,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 52}
# sourcelocation: amherst
# pk_uuid: 03D2E95BC76E29439E77958A6F57DB08
# number: 580
# firstname: Robert
# lastname: Enright
# dept: Engineering
# RoleGroup: Supply Chain,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 53}
# sourcelocation: amherst
# pk_uuid: 37957A34C06DA04D951B689D6E13A9B5
# number: 1254
# firstname: Emanuel
# lastname: Ramirez
# dept: Logistics
# RoleGroup: Supply Chain,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 54}
# sourcelocation: amherst
# pk_uuid: 42DDD2492023E048A1316D8335547938
# number: 1395
# firstname: Kaelin
# lastname: Mcclary
# dept: Logistics
# RoleGroup: Supply Chain,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 55}
# sourcelocation: amherst
# pk_uuid: 74152E2486500B48B2ADBB2430F7847E
# number: 1244
# firstname: Yash
# lastname: Dhote
# dept: Manager
# RoleGroup: Supply Chain,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 56}
# sourcelocation: amherst
# pk_uuid: 7D62D1477665B8489704B930E325CDE2
# number: 1389
# firstname: Gellert
# lastname: Kish
# dept: Technology
# RoleGroup: Supply Chain,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 57}
# sourcelocation: amherst
# pk_uuid: DD608BEE133ACE49A8DC07184832F3B6
# number: 647
# firstname: Ken
# lastname: Fenske
# dept: Logistics
# RoleGroup: Supply Chain,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 58}
# sourcelocation: amherst
# pk_uuid: F1D91A10922F064EB04D99C89B09C1C9
# number: 1398
# firstname: Phillip
# lastname: Beutler
# dept: Logistics
# RoleGroup: Supply Chain,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 59}
# sourcelocation: amherst
# pk_uuid: 1525160378511A4685F3174C58A2CC5F
# number: 1397
# firstname: Jennifer
# lastname: Wood
# dept: Quality
# RoleGroup: Quality Control,Supply Chain,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 60}
# sourcelocation: amherst
# pk_uuid: AC69582C18B5224496E8CB56654BBFEA
# number: 1387
# firstname: Adam
# lastname: Naga
# dept: QC
# RoleGroup: Quality Control,Supply Chain,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 61}
# sourcelocation: amherst
# pk_uuid: EECD8FA14C01594AB83518A19CDFF055
# number: 1253
# firstname: Joel
# lastname: Barlow
# dept: Logistics
# RoleGroup: Quality Control,Supply Chain,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 62}
# sourcelocation: amherst
# pk_uuid: 5FF07FAA5B639446B9379F95704D38B4
# number: 585
# firstname: Andrew
# lastname: Sharp
# dept: Sales & Marketing
# RoleGroup: Quality Control,Information Technology,Supply Chain,Standard Press & Finishing,Accounting Leadership,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 63}
# sourcelocation: amherst
# pk_uuid: 238859A5602D214F9720B1A5C58F1846
# number: 1120
# firstname: Ali
# lastname: Natiq
# dept: Production Support
# RoleGroup: Quality Control,Supply Chain,Standard Press & Finishing,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 64}
# sourcelocation: amherst
# pk_uuid: 3C067632802B5C4AA60E05EC8AEBE845
# number: 985
# firstname: Matt
# lastname: Moore
# dept: Production Support
# RoleGroup: Quality Control,Supply Chain,Standard Press & Finishing,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 65}
# sourcelocation: amherst
# pk_uuid: 484C34B6A068CD47913FC9126760E813
# number: 1290
# firstname: Lavan
# lastname: Sivanolipatham
# dept: Production Support
# RoleGroup: Quality Control,Supply Chain,Standard Press & Finishing,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 66}
# sourcelocation: amherst
# pk_uuid: 8FDE9B50BA603947AFA259785F71CB82
# number: 1296
# firstname: Lavan
# lastname: Sivanolipatham
# dept: Production Support
# RoleGroup: Quality Control,Supply Chain,Standard Press & Finishing,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 67}
# sourcelocation: amherst
# pk_uuid: B361139EFD14EC44A9BF60039D5B85C9
# number: 1289
# firstname: Amador
# lastname: Caraballo
# dept: Production Support
# RoleGroup: Quality Control,Supply Chain,Standard Press & Finishing,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 68}
# sourcelocation: amherst
# pk_uuid: C3D670EBEE1447438841E7F2C445E2FC
# number: 1297
# firstname: Amador
# lastname: Caraballo
# dept: Production Support
# RoleGroup: Quality Control,Supply Chain,Standard Press & Finishing,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 69}
# sourcelocation: amherst
# pk_uuid: E890E243AB21CC40A24889ECD10F9217
# number: 678
# firstname: Dennis
# lastname: Ayers
# dept: Production Support
# RoleGroup: Quality Control,Supply Chain,Standard Press & Finishing,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 70}
# sourcelocation: amherst
# pk_uuid: 062A6BA420713546A7E3152F527C3A56
# number: 1396
# firstname: Jessica
# lastname: Jaroszewski
# dept: Quality
# RoleGroup: Quality Control,Supply Chain,Accounting Leadership,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 71}
# sourcelocation: amherst
# pk_uuid: 843BB7CB502B824886A3C4FD52ABD7D0
# number: 715
# firstname: William
# lastname: Burgess
# dept: QC
# RoleGroup: Quality Control,Supply Chain,Accounting Leadership,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 72}
# sourcelocation: amherst
# pk_uuid: 968BFDE90E7D0D4CA6A5F2FC599E1B19
# number: 1238
# firstname: Christie
# lastname: Jean
# dept: QC
# RoleGroup: Quality Control,Supply Chain,Accounting Leadership,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 73}
# sourcelocation: amherst
# pk_uuid: B85837C933CBAE4C9DF426CC0121740F
# number: 698
# firstname: Nerol
# lastname: Jean
# dept: QC
# RoleGroup: Quality Control,Supply Chain,Accounting Leadership,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 74}
# sourcelocation: amherst
# pk_uuid: F8C2AC815367BE49A4991E0401C8DDE2
# number: 970
# firstname: Daniel
# lastname: Thornton
# dept: QC
# RoleGroup: Quality Control,Supply Chain,Accounting Leadership,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 75}
# sourcelocation: amherst
# pk_uuid: FCEC9F545332EC46B220CED90ED831F0
# number: 1366
# firstname: Peter
# lastname: Kvam
# dept: Manager
# RoleGroup: Quality Control,Supply Chain,Accounting Leadership,Estimating Team,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 76}
# sourcelocation: amherst
# pk_uuid: 58C87DE22331EF4AB89FEE4255EF350F
# number: 1096
# firstname: Brian
# lastname: Soika
# dept: Roto 12
# RoleGroup: Supply Chain,Standard Press & Finishing,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 77}
# sourcelocation: amherst
# pk_uuid: 6F939C6039A7C54A8FBB0969653844B9
# number: 780
# firstname: Steven
# lastname: Stewart
# dept: Sales & Marketing
# RoleGroup: Supply Chain,Standard Press & Finishing,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 78}
# sourcelocation: amherst
# pk_uuid: 748E5DDBBFFB5642A2F1005F3A5A0A15
# number: 1131
# firstname: Logan
# lastname: Misseldine
# dept: ETI
# RoleGroup: Supply Chain,Standard Press & Finishing,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 79}
# sourcelocation: amherst
# pk_uuid: 344B3F95755453488D23B8CD194C4DE9
# number: 1332
# firstname: Scott
# lastname: Thomas
# dept: IT
# RoleGroup: Information Technology
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 80}
# sourcelocation: amherst
# pk_uuid: F3620BDF83316946A39A673C432D6B32
# number: 1386
# firstname: Scott
# lastname: Wamsley
# dept: IT
# RoleGroup: Information Technology
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 81}
# sourcelocation: amherst
# pk_uuid: 1C3A3570DAE85148B772F8A59E11D44F
# number: 1384
# firstname: Dan
# lastname: Zeller
# dept: IT
# RoleGroup: Information Technology
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 82}
# sourcelocation: amherst
# pk_uuid: 46083214897BFD43A53323A4D80C137D
# number: 1294
# firstname: Dan
# lastname: Kabbes
# dept: IT
# RoleGroup: Information Technology
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 83}
# sourcelocation: amherst
# pk_uuid: 4B1AA05F3BAE7343B07FB8F625D353A3
# number: 1365
# firstname: Nick
# lastname: Thomasson
# dept: IT
# RoleGroup: Information Technology
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 84}
# sourcelocation: amherst
# pk_uuid: DF76B416E795564BB3E342582C12D83F
# number: 1364
# firstname: Thomas
# lastname: Santry
# dept: IT
# RoleGroup: Information Technology
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 85}
# sourcelocation: amherst
# pk_uuid: 3536E87772BDA24AAA302361127891A4
# number: 1385
# firstname: Richard
# lastname: Wight
# dept: IT
# RoleGroup: Information Technology
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 86}
# sourcelocation: amherst
# pk_uuid: EB86B08CCC25324D942DE24F813F5D60
# number: 1355
# firstname: Nate
# lastname: Seitz
# dept: IT
# RoleGroup: Information Technology
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 87}
# sourcelocation: amherst
# pk_uuid: C50710F35F03F842AA385171F6801B3A
# number: 1354
# firstname: Sam
# lastname: Doty
# dept: IT
# RoleGroup: Information Technology
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 88}
# sourcelocation: amherst
# pk_uuid: 7F5B3AEFDBBC61469B91DC20E779BC5C
# number: 1353
# firstname: Stephen
# lastname: Thackston
# dept: IT
# RoleGroup: Information Technology
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 89}
# sourcelocation: amherst
# pk_uuid: 2CC650EDA5D3E34E9112DFC1A3A73F4C
# number: 1382
# firstname: Sam
# lastname: Frazier
# dept: Logistics
# RoleGroup: Supply Chain,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 90}
# sourcelocation: amherst
# pk_uuid: 3EE951106041BF4790C2502F4B92146E
# number: 1399
# firstname: Bill
# lastname: Rappold
# dept: Ink
# RoleGroup: Supply Chain,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 91}
# sourcelocation: amherst
# pk_uuid: 50CD60513BAAEF4B813129FA629BD317
# number: 992
# firstname: Kadhum
# lastname: Al-Salman
# dept: Logistics
# RoleGroup: Supply Chain,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 92}
# sourcelocation: amherst
# pk_uuid: 89F0327BB9DAF8468BA9E2A3B88A77DD
# number: 1363
# firstname: LaKeisha
# lastname: Godbold-Semonin
# dept: Manager
# RoleGroup: Supply Chain,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 93}
# sourcelocation: amherst
# pk_uuid: 9513E1B356CCE94CA9F1A9E05A9E1614
# number: 1176
# firstname: Vernette
# lastname: Jean
# dept: Logistics
# RoleGroup: Supply Chain,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 94}
# sourcelocation: amherst
# pk_uuid: AF98D0875045E849A6368B8991A55B04
# number: 1361
# firstname: Norman
# lastname: Winters
# dept: Logistics
# RoleGroup: Supply Chain,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 95}
# sourcelocation: amherst
# pk_uuid: B379D122079B804B9188A8825122974E
# number: 1028
# firstname: Evelyn
# lastname: Ravens
# dept: Sales & Marketing
# RoleGroup: Supply Chain,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 96}
# sourcelocation: amherst
# pk_uuid: C231C0E6A6D88F4FAA7BB5D66D56073E
# number: 1173
# firstname: James
# lastname: Wachowiak
# dept: Ink
# RoleGroup: Supply Chain,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 97}
# sourcelocation: amherst
# pk_uuid: C883AF26B5268647B4C6C4BD537C9461
# number: 1262
# firstname: David
# lastname: Martinez
# dept: Production Support
# RoleGroup: Supply Chain,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 98}
# sourcelocation: amherst
# pk_uuid: EFE8ED967A08734C8964F41699D250F1
# number: 1034
# firstname: Karen
# lastname: Breden
# dept: Sales & Marketing
# RoleGroup: Supply Chain,Customer Service
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_amherst.csv', 'row': 99}
# sourcelocation: amherst
# pk_uuid: F2DC7475D45A0A4B8253FDB23448901A
# number: 1174
# firstname: Jerris
# lastname: Brandon
# dept: Logistics
# RoleGroup: Supply Chain,Customer Service
# ---------------------
# ...
# sourcelocation: st_louis
# pk_uuid: 255E96D1F31F1D428A857B99E2A2F71E
# number: 519
# firstname: Nick
# lastname: Hardaway
# dept: Prepress - Time
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 360}
# sourcelocation: st_louis
# pk_uuid: 434CDA608FCA73408E8A25D2FA2D722B
# number: 527
# firstname: Christopher
# lastname: Preis
# dept: Prepress - Time
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 361}
# sourcelocation: st_louis
# pk_uuid: 5290D693341ACE4297DEE29B12AF7E63
# number: 741
# firstname: Daniel
# lastname: Clark
# dept: Prepress - Time
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 362}
# sourcelocation: st_louis
# pk_uuid: 622FB1B64780DA47A18CA161D00A7562
# number: 1482
# firstname: Zalyn
# lastname: Fleming
# dept: Prepress - Time
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 363}
# sourcelocation: st_louis
# pk_uuid: 882504B2ADB6E742914210FE8CDD3DEC
# number: 1850
# firstname: Martez
# lastname: Cobbs
# dept: Prepress - Time
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 364}
# sourcelocation: st_louis
# pk_uuid: A65DBE406D2DD141A208899338719827
# number: 1676
# firstname: Don
# lastname: Watson
# dept: Prepress - Time
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 365}
# sourcelocation: st_louis
# pk_uuid: C5ADFBA2414DC447A93A2614725FB37F
# number: 1199
# firstname: Tyler
# lastname: Huddleston
# dept: Prepress - Time
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 366}
# sourcelocation: st_louis
# pk_uuid: C9E182597E0B3F47AC6D4301360345EA
# number: 1371
# firstname: Conner
# lastname: Langford
# dept: Prepress - Time
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 367}
# sourcelocation: st_louis
# pk_uuid: FAA9F6EE0B77E24693F1415D06EF99DF
# number: 815
# firstname: Kain
# lastname: Cook
# dept: Prepress - Time
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 368}
# sourcelocation: st_louis
# pk_uuid: 0A39387B98B75F4F97E5D9602D3D6844
# number: 1211
# firstname: Tyson
# lastname: Bauer
# dept: TN - Press
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 369}
# sourcelocation: st_louis
# pk_uuid: 122249071E0123419B59A7F6D97B09FC
# number: 1808
# firstname: Ryan
# lastname: Johnson
# dept: TN - Press
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 370}
# sourcelocation: st_louis
# pk_uuid: 19D9E5D98AACFB4991D054A15006BFB4
# number: 1491
# firstname: Donald
# lastname: Colwart
# dept: TN - Press
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 371}
# sourcelocation: st_louis
# pk_uuid: 1E137E4F571EA84C8FE6959F98ED024F
# number: 1252
# firstname: Jaime
# lastname: Mancilla
# dept: TN - Press
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 372}
# sourcelocation: st_louis
# pk_uuid: 211C54E6ACAB824D8482A5B7A8F6BB80
# number: 1510
# firstname: Jhonte
# lastname: McAvoy
# dept: TN - Press
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 373}
# sourcelocation: st_louis
# pk_uuid: 249BAACB1719D443A663A8C41DEF47FB
# number: 773
# firstname: Brandon
# lastname: Disney
# dept: TN - Press
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 374}
# sourcelocation: st_louis
# pk_uuid: 34D9725DD1DD404EAD0DC70229D869BE
# number: 1314
# firstname: Danny
# lastname: Naranjo
# dept: TN - Press
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 375}
# sourcelocation: st_louis
# pk_uuid: 6A9F1C9FE83DAD418923790DFD4847E0
# number: 1820
# firstname: Marcus
# lastname: Cade
# dept: TN - Press
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 376}
# sourcelocation: st_louis
# pk_uuid: ACFC0B8D3707B54E944F3BBFA13EF98A
# number: 1352
# firstname: Adel
# lastname: Azer
# dept: TN - Press
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 377}
# sourcelocation: st_louis
# pk_uuid: FB3CC8F6B36692488A848627C9F10F52
# number: 182
# firstname: Angel
# lastname: Santiago
# dept: TN - Press
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 378}
# sourcelocation: st_louis
# pk_uuid: 0F3146AB0C8FF04789E37E393E49F30C
# number: 158
# firstname: Douglas
# lastname: Chapman
# dept: TN - Maintenance
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 379}
# sourcelocation: st_louis
# pk_uuid: 1D9EED4CA8FDB34189138535E424FA1F
# number: 1472
# firstname: Tim
# lastname: Nettles
# dept: Digital Press
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 380}
# sourcelocation: st_louis
# pk_uuid: 1DB52617F07C964599FA64698D87FBFE
# number: 422
# firstname: Robert
# lastname: Henry
# dept: Digital Press
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 381}
# sourcelocation: st_louis
# pk_uuid: 2196E8255521F8469866A75B2DFB14BB
# number: 294
# firstname: Casey
# lastname: Brakeville
# dept: S.A.D.
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 382}
# sourcelocation: st_louis
# pk_uuid: 2A370E84EA9C8B409525E88F2F6989EB
# number: 564
# firstname: SADP
# lastname: TimeClock
# dept: R&D dept.
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 383}
# sourcelocation: st_louis
# pk_uuid: 2E07592D6C791D49A3D9B0FE8AC5C13F
# number: 697
# firstname: Melinda
# lastname: Corter
# dept: TN -InkTech
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 384}
# sourcelocation: st_louis
# pk_uuid: 2F24F7D72510EF4E95766BC36E2A5FE1
# number: 134
# firstname: Michael
# lastname: Wildhaber
# dept: Digital Press
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 385}
# sourcelocation: st_louis
# pk_uuid: 36BB1BA78AF99546AC17490E006698C4
# number: 337
# firstname: Scott
# lastname: Collett
# dept: ePrepress - Time
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 386}
# sourcelocation: st_louis
# pk_uuid: 39FF361B075D6F4EAF07D2BFB88EE582
# number: 490
# firstname: Temp
# lastname: TN
# dept: TN - Prepress
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 387}
# sourcelocation: st_louis
# pk_uuid: 3D3732E1996BB54489F25D01E59895FD
# number: 306
# firstname: Christopher
# lastname: Carver
# dept: S.A.D.
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 388}
# sourcelocation: st_louis
# pk_uuid: 3EC9D4DF3AE02F4E9009C227B64B7B61
# number: 1407
# firstname: Quan
# lastname: Pham
# dept: Press_3rd_Shift
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 389}
# sourcelocation: st_louis
# pk_uuid: 41AB67BB977AED4FB2BEDA50EF71AAEC
# number: 1846
# firstname: Damyen
# lastname: Burns
# dept: Press
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 390}
# sourcelocation: st_louis
# pk_uuid: 41C22ED47E3D3641A28231E25627804D
# number: 1870
# firstname: Lucas
# lastname: Hansen
# dept: Press
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 391}
# sourcelocation: st_louis
# pk_uuid: 48348DC2DF7EB644831E8F1540787CA6
# number: 1822
# firstname: Courtney
# lastname: Thomas
# dept: Press
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 392}
# sourcelocation: st_louis
# pk_uuid: 4EE7F45491D1D54485816D0C4EE57839
# number: 398
# firstname: Ryan
# lastname: VanderMeulen
# dept: Digital Press
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 393}
# sourcelocation: st_louis
# pk_uuid: 54831CB06BF5E24A8E8A192E8F3D4C1B
# number: 1839
# firstname: Robbie
# lastname: Torrey
# dept: Press
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 394}
# sourcelocation: st_louis
# pk_uuid: 5693D79A31F6BA4EA763F84D7D45F8D4
# number: 707
# firstname: Scott
# lastname: Yoder
# dept: Digital Press
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 395}
# sourcelocation: st_louis
# pk_uuid: 626EE4465F805349BAC52D3AC621B646
# number: 756
# firstname: Jeff
# lastname: Davis
# dept: Press_3rd_Shift
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 396}
# sourcelocation: st_louis
# pk_uuid: 661C57EC00895B42B8D0C0105A5D4429
# number: 187
# firstname: Laester
# lastname: Smith
# dept: TN - Inspection
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 397}
# sourcelocation: st_louis
# pk_uuid: 6644B758B0F58B4B9FB8F07BD6DCC86C
# number: 479
# firstname: Nick
# lastname: Time Card
# dept: S.A.D.
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 398}
# sourcelocation: st_louis
# pk_uuid: 6B6227D3556694428D6728127D9084C1
# number: 1864
# firstname: Sergio
# lastname: Garcia
# dept: Press
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 399}
# sourcelocation: st_louis
# pk_uuid: 7E0E18C01C42B84A9C3B7CD91579D865
# number: 1783
# firstname: Chuck
# lastname: Benedick
# dept: Quality Control
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 400}
# sourcelocation: st_louis
# pk_uuid: 824FB286257C424785E1C82C14C69F22
# number: 40
# firstname: Richard
# lastname: Gaffney
# dept: Press_3rd_Shift
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 401}
# sourcelocation: st_louis
# pk_uuid: 87C2B3078A3E9044B063874540C025AB
# number: 57
# firstname: Bob
# lastname: Hertel
# dept: Quality Control-Time
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 402}
# sourcelocation: st_louis
# pk_uuid: 8FB88B909B798F468D61A3165D1F6F3A
# number: 563
# firstname: Press
# lastname: TimeClock
# dept: R&D dept.
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 403}
# sourcelocation: st_louis
# pk_uuid: 95C0156CD26E5E489CD104C5A211603A
# number: 982
# firstname: Dylan
# lastname: Kemper
# dept: Digital Press
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 404}
# sourcelocation: st_louis
# pk_uuid: 9623B399A6012F409102C923DF88AAA2
# number: 309
# firstname: Terry
# lastname: Ramsey
# dept: S.A.D.
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 405}
# sourcelocation: st_louis
# pk_uuid: 970E42BD3A595D4BAFBA65AECF2B589B
# number: 1819
# firstname: Justin
# lastname: Dunkle
# dept: TN - Inspection
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 406}
# sourcelocation: st_louis
# pk_uuid: 9CC8A51B1F7AD64CA627FF59643B989A
# number: 1337
# firstname: David
# lastname: Parvin
# dept: Digital Press
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 407}
# sourcelocation: st_louis
# pk_uuid: A461C88DF3F3B844BED43B361512A49B
# number: 1241
# firstname: Tim
# lastname: Haptonstall
# dept: Press_3rd_Shift
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 408}
# sourcelocation: st_louis
# pk_uuid: A9FF2D6C84123A4997C21BCE957BEAB4
# number: 1525
# firstname: Jeanette
# lastname: Vazquez
# dept: TN - Inspection
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 409}
# sourcelocation: st_louis
# pk_uuid: B33A0BE0C8D3DD40B81B8121C336F6F8
# number: 1150
# firstname: Samuel
# lastname: Frazier
# dept: S.A.D.
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 410}
# sourcelocation: st_louis
# pk_uuid: B8F4425BC992C44F8253C48E1C607A70
# number: 1031
# firstname: Thomas
# lastname: Latimer
# dept: ePrepress - Time
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 411}
# sourcelocation: st_louis
# pk_uuid: C247E05F8E6AF14999152CC1B705071A
# number: 1341
# firstname: Alemtsahey
# lastname: Negash
# dept: TN - Inspection
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 412}
# sourcelocation: st_louis
# pk_uuid: C9B886FF0F453E499C0B97B4CDF0C2E0
# number: 701
# firstname: Sandeep
# lastname: Jagtap
# dept: S.A.D.
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 413}
# sourcelocation: st_louis
# pk_uuid: CBB2BD153C30AF479D437EBD3E3D2ECC
# number: 1869
# firstname: Desirea
# lastname: Lamb
# dept: Press
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 414}
# sourcelocation: st_louis
# pk_uuid: D527BF827BFBA94096A7D01F818B4EF6
# number: 674
# firstname: Tim
# lastname: Peterein
# dept: ePrepress - Time
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 415}
# sourcelocation: st_louis
# pk_uuid: D9E60EB611A95E4EA35E17CA6B7F928A
# number: 1108
# firstname: Dave
# lastname: Hasekamp
# dept: S.A.D.
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 416}
# sourcelocation: st_louis
# pk_uuid: DAF82A212A0BB147B19A5F8923C4E2D4
# number: 471
# firstname: Michael
# lastname: Felten
# dept: TN - Prepress
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 417}
# sourcelocation: st_louis
# pk_uuid: DD2DA3959B56FA40814ABB2DE69E8703
# number: 1527
# firstname: Alberto
# lastname: Santiago
# dept: ePrepress - Time
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 418}
# sourcelocation: st_louis
# pk_uuid: DEAB3E175E942C4DA4864D699FDC400D
# number: 1487
# firstname: Barry
# lastname: Nichols
# dept: TN - Inspection
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 419}
# sourcelocation: st_louis
# pk_uuid: E4F56FAAC4AFF043939EF72D766C794C
# number: 987
# firstname: Cathlee
# lastname: Gant
# dept: Press_3rd_Shift
# RoleGroup: Standard Press & Finishing
# ---------------------
# {'source': '..\\data\\csv\\labeltraxx_st_louis.csv', 'row': 420}
# sourcelocation: st_louis
# pk_uuid: F9066117AC2E674A92572F0283BB676B
# number: 696
# firstname: Donna
# lastname: Hynes
# dept: Quality Control-Time
# RoleGroup: Standard Press & Finishing
# ---------------------
